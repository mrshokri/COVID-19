# %% [markdown]
# ### Effectiveness of drugs being developed and tried to treat COVID-19 patients

# %% [markdown]
# ### 1. Introduction
# write intro here

# %% [markdown]
# ### 2. Notebook’s Goal
# The goal of this notebook is to help the medical community in finding answers to the questions below as it relates to COVID-19. Using data science as well as data mining techniques, and tools, this notebook intends to assist the medical community in quickly finding the most relevant scholarly articles that could help answer these questions.

# %% [markdown]
# ### 3. Methodology
# The workflow in the figure bellow illustrates the approach taken pre-process, model, and post-process the cord-19 data set.
#
# The first step is the pre-processing. It involves basic data cleansing across the dataset, applying a proper selection of the paper’s language, availability of full research document, and other basic elements. At the core of the modeling step, a Natural Language Processing (NLP) library is found (1). It provides the possibility to execute different tasks like clustering, summarization, phrase matching, a ranking of the given research papers.
#
# Finally, the selection of the most relevant documents is conducted considering the representation of presented words and sentences using a vector form. This functionality provides a way to measure the semantic similarity of a given search sub-task.

# %% [markdown]
# #### 3.1 Pre-processing

# %% [markdown]
# ##### 3.1.1 Dataset description
# Each paper in the dataset is represented by a JSON file. For each paper, we want to extract the following data:
# - paper ID
# - publication date
# - title
# - abstract text
# - body text
# - primary location and country for the author(s)
#
# ##### 3.1.2 Data cleaning
# The following steps were considered for dataset cleaning:
#
# - Remove unnecessary or unhelpful characters and words from the paper text
# - Remove duplicate papers
# - Remove papers which are not in English
# - Eliminate null values
# - Remove blank space
# - Removes references and annotations

# %% [markdown]
# Import Reuired Libraries

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import explode

# %% [markdown]
# ### 1. ETL

# %% [markdown]
# #### 1.1 Create SparkSession and SparkContext

# %%
spark = SparkSession.builder.appName("COVID-19 Effective Drugs").master("local[3]").getOrCreate()

# %% [markdown]
# Read data from given path

# %%
path = "data"
raw_df = spark.read.json(path, multiLine="true")

# %% [markdown]
# Explore DataFrame Schema

# %%
raw_df.printSchema()
# raw_df.show(1, True)
# Out:
# root
#  |-- abstract: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- cite_spans: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- end: long (nullable = true)
#  |    |    |    |    |-- ref_id: string (nullable = true)
#  |    |    |    |    |-- start: long (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |-- ref_spans: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- section: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |-- back_matter: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- cite_spans: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- end: long (nullable = true)
#  |    |    |    |    |-- ref_id: string (nullable = true)
#  |    |    |    |    |-- start: long (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |-- ref_spans: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- end: long (nullable = true)
#  |    |    |    |    |-- ref_id: string (nullable = true)
#  |    |    |    |    |-- start: long (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |-- section: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |-- bib_entries: struct (nullable = true)
#  |    |-- BIBREF0: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- other_ids: struct (nullable = true)
#  |    |    |    |-- DOI: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF1: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- other_ids: struct (nullable = true)
#  |    |    |    |-- DOI: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF10: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- other_ids: struct (nullable = true)
#  |    |    |    |-- DOI: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF100: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF101: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF102: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF103: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF104: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF105: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF106: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF107: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF108: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF109: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF11: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- other_ids: struct (nullable = true)
#  |    |    |    |-- DOI: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF110: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF111: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF112: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF113: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF114: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF115: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF116: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF117: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF118: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF119: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF12: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- other_ids: struct (nullable = true)
#  |    |    |    |-- DOI: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF120: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF121: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF122: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF123: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF125: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF126: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF127: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF128: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF129: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF13: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- other_ids: struct (nullable = true)
#  |    |    |    |-- DOI: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF130: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF131: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF132: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF133: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF134: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF135: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF136: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF137: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF138: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF139: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF14: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- other_ids: struct (nullable = true)
#  |    |    |    |-- DOI: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF140: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF141: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF142: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF143: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF144: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF145: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF146: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF147: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF148: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF149: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF15: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- other_ids: struct (nullable = true)
#  |    |    |    |-- DOI: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF150: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF151: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
# ...
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- other_ids: struct (nullable = true)
#  |    |    |    |-- DOI: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF90: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF91: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF92: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF93: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF94: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF95: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF96: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF97: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF98: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |    |-- BIBREF99: struct (nullable = true)
#  |    |    |-- authors: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- suffix: string (nullable = true)
#  |    |    |-- issn: string (nullable = true)
#  |    |    |-- pages: string (nullable = true)
#  |    |    |-- ref_id: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- venue: string (nullable = true)
#  |    |    |-- volume: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |-- body_text: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- cite_spans: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- end: long (nullable = true)
#  |    |    |    |    |-- ref_id: string (nullable = true)
#  |    |    |    |    |-- start: long (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |-- ref_spans: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- end: long (nullable = true)
#  |    |    |    |    |-- ref_id: string (nullable = true)
#  |    |    |    |    |-- start: long (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |-- section: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |-- metadata: struct (nullable = true)
#  |    |-- authors: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- affiliation: struct (nullable = true)
#  |    |    |    |    |-- institution: string (nullable = true)
#  |    |    |    |    |-- laboratory: string (nullable = true)
#  |    |    |    |    |-- location: struct (nullable = true)
#  |    |    |    |    |    |-- addrLine: string (nullable = true)
#  |    |    |    |    |    |-- country: string (nullable = true)
#  |    |    |    |    |    |-- postCode: string (nullable = true)
#  |    |    |    |    |    |-- region: string (nullable = true)
#  |    |    |    |    |    |-- settlement: string (nullable = true)
#  |    |    |    |-- email: string (nullable = true)
#  |    |    |    |-- first: string (nullable = true)
#  |    |    |    |-- last: string (nullable = true)
#  |    |    |    |-- middle: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- suffix: string (nullable = true)
#  |    |-- title: string (nullable = true)
#  |-- paper_id: string (nullable = true)
#  |-- ref_entries: struct (nullable = true)
#  |    |-- FIGREF0: struct (nullable = true)
#  |    |    |-- latex: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- FIGREF1: struct (nullable = true)
#  |    |    |-- latex: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- FIGREF10: struct (nullable = true)
#  |    |    |-- latex: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- FIGREF11: struct (nullable = true)
#  |    |    |-- latex: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- FIGREF12: struct (nullable = true)
#  |    |    |-- latex: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- FIGREF13: struct (nullable = true)
#  |    |    |-- latex: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- FIGREF14: struct (nullable = true)
#  |    |    |-- latex: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- FIGREF15: struct (nullable = true)
#  |    |    |-- latex: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- FIGREF16: struct (nullable = true)
#  |    |    |-- latex: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- FIGREF18: struct (nullable = true)
#  |    |    |-- latex: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- FIGREF19: struct (nullable = true)
#  |    |    |-- latex: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- FIGREF2: struct (nullable = true)
#  |    |    |-- latex: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- FIGREF20: struct (nullable = true)
#  |    |    |-- latex: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- FIGREF21: struct (nullable = true)
#  |    |    |-- latex: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- FIGREF22: struct (nullable = true)
#  |    |    |-- latex: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- FIGREF23: struct (nullable = true)
#  |    |    |-- latex: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- FIGREF24: struct (nullable = true)
#  |    |    |-- latex: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- FIGREF3: struct (nullable = true)
#  |    |    |-- latex: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- FIGREF4: struct (nullable = true)
#  |    |    |-- latex: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- FIGREF5: struct (nullable = true)
#  |    |    |-- latex: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- FIGREF6: struct (nullable = true)
#  |    |    |-- latex: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- FIGREF7: struct (nullable = true)
#  |    |    |-- latex: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- FIGREF8: struct (nullable = true)
#  |    |    |-- latex: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- FIGREF9: struct (nullable = true)
#  |    |    |-- latex: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- TABREF0: struct (nullable = true)
#  |    |    |-- latex: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- TABREF1: struct (nullable = true)
#  |    |    |-- latex: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- TABREF2: struct (nullable = true)
#  |    |    |-- latex: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- TABREF3: struct (nullable = true)
#  |    |    |-- latex: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- TABREF4: struct (nullable = true)
#  |    |    |-- latex: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- TABREF5: struct (nullable = true)
#  |    |    |-- latex: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- TABREF6: struct (nullable = true)
#  |    |    |-- latex: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- TABREF7: struct (nullable = true)
#  |    |    |-- latex: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- type: string (nullable = true)

# %% [markdown]
# Creating a row for each text element inside body text: explode

# %%
body_text_item_df = raw_df.select("paper_id", explode("body_text.text").alias("body_text_item"))
# body_text_item_df.printSchema()
body_text_item_df.show(10, truncate=True)
# Out:
# +--------------------+--------------------+
# |            paper_id|      body_text_item|
# +--------------------+--------------------+
# |00a0ab182dc01b6c2...|The world was mad...|
# |00a0ab182dc01b6c2...|Patients with MER...|
# |00a0ab182dc01b6c2...|Chest radiography...|
# |00a0ab182dc01b6c2...|The mean incubati...|
# |00a0ab182dc01b6c2...|MERS can progress...|
# |00a0ab182dc01b6c2...|As a group, child...|
# |00a0ab182dc01b6c2...|The virus associa...|
# |00a0ab182dc01b6c2...|MERS-CoV is a put...|
# |00a0ab182dc01b6c2...|Complete genome d...|
# |00a0ab182dc01b6c2...|To date, the MERS...|
# +--------------------+--------------------+
# only showing top 10 rows

# %% [markdown]
# ## Pre-processing
# Each paper in the dataset is represented by a JSON file. For each paper, we want to extract the following data:
# - paper ID
# - publication date
# - title
# - abstract text
# - body text
# - primary location and country for the author(s)
